# %%
# !pip2 install tensorflow-gpu==1.14
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/41/6d/2348df00a34baaabdef0fdb4f46f962f7a8a6720362c26c3a44a249767ea/tensorflow_gpu-1.14.0-cp27-cp27mu-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 40kB/s
# Collecting grpcio>=1.8.6
#   Downloading https://files.pythonhosted.org/packages/bd/81/6c704c002a992b9d6466c739e3e7687e0bb2365d8cd63d7fc8e95d502cb6/grpcio-1.41.1.tar.gz (21.2MB)
#      |████████████████████████████████| 21.2MB 1.3MB/s
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/21/56/4bcec5a8d9503a87e58e814c4e32ac2b32c37c685672c30bc8c54c6e478a/Keras_Applications-1.0.8.tar.gz (289kB)
#      |████████████████████████████████| 296kB 52.3MB/s
# Collecting enum34>=1.1.6
#   Downloading https://files.pythonhosted.org/packages/6f/2c/a9386903ece2ea85e9807e0e062174dc26fdce8b05f216d00491be29fad5/enum34-1.1.10-py2-none-any.whl
# Collecting wrapt>=1.11.1
#   Downloading https://files.pythonhosted.org/packages/e6/57/d5673f5201ccbc287e70a574868319267735de3041e496e1e26b48d8f653/wrapt-1.14.1-cp27-cp27mu-manylinux2010_x86_64.whl (75kB)
#      |████████████████████████████████| 81kB 5.9MB/s
# Collecting protobuf>=3.6.1
#   Downloading https://files.pythonhosted.org/packages/e9/06/5606088c9fbfb924d0f228350e7ec8707fe8f8a6f3a024ace4f0da81d9ce/protobuf-3.17.3-cp27-cp27mu-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 43.1MB/s
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 8.0MB/s
# Collecting gast>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/48/a3/0bd844c54ae8141642088b7ae09dd38fec2ec7faa9b7d25bb6a23c1f266f/gast-0.5.3.tar.gz
# Requirement already satisfied: wheel in /usr/local/lib/python2.7/dist-packages (from tensorflow-gpu==1.14) (0.37.1)
# Collecting numpy<2.0,>=1.14.5
#   Downloading https://files.pythonhosted.org/packages/3a/5f/47e578b3ae79e2624e205445ab77a1848acdaa2929a00eeef6b16eaaeb20/numpy-1.16.6-cp27-cp27mu-manylinux1_x86_64.whl (17.0MB)
#      |████████████████████████████████| 17.0MB 984kB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/f4/37/e6a7af1c92c5b68fb427f853b06164b56ea92126bcfd87784334ec5e4d42/tensorboard-1.14.0-py2-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 45.0MB/s
# Collecting termcolor>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting six>=1.10.0
#   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting absl-py>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/25/d9/22a0b010487da88200c3f0672c67e892b5399b7a13d105d3863511399f6e/absl-py-0.15.0.tar.gz (114kB)
#      |████████████████████████████████| 122kB 46.6MB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 47.1MB/s
# Collecting google-pasta>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/59/22/38238cd9b83dd8a857abd7c907b8fe68ceff1611ab3ca5f0e80a5e025956/google_pasta-0.2.0-py2-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 9.8MB/s
# Collecting backports.weakref>=1.0rc1
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting astor>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl
# Collecting futures>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/d8/a6/f46ae3f1da0cd4361c344888f59ec2f5785e69c872e175a748ef6071cdb5/futures-3.3.0-py2-none-any.whl
# Collecting funcsigs>=1; python_version < "3.3"
#   Downloading https://files.pythonhosted.org/packages/69/cb/f5be453359271714c01b9bd06126eaf2e368f1fddfff30818754b5ac2328/funcsigs-1.0.2-py2.py3-none-any.whl
# Collecting h5py
#   Downloading https://files.pythonhosted.org/packages/12/90/3216b8f6d69905a320352a9ca6802a8e39fdb1cd93133c3d4163db8d5f19/h5py-2.10.0-cp27-cp27mu-manylinux1_x86_64.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 41.4MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (44.1.1)
# Collecting werkzeug>=0.11.15
#   Downloading https://files.pythonhosted.org/packages/cc/94/5f7079a0e00bd6863ef8f1da638721e9da21e5bacee597595b318f71d62e/Werkzeug-1.0.1-py2.py3-none-any.whl (298kB)
#      |████████████████████████████████| 307kB 57.0MB/s
# Collecting markdown>=2.6.8
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 11.7MB/s
# Building wheels for collected packages: grpcio, keras-applications, gast, termcolor, absl-py
#   Building wheel for grpcio (setup.py) ... done
#   Created wheel for grpcio: filename=grpcio-1.41.1-cp27-cp27mu-linux_x86_64.whl size=33844662 sha256=c85698ec0f562a6f5f59eb54439c4f7aa2e4756229eac2cbaa6644b643845815
#   Stored in directory: /root/.cache/pip/wheels/c4/93/65/a16057b837ece5b0b2a2a16253dfa7a649352db2e7370179e8
#   Building wheel for keras-applications (setup.py) ... done
#   Created wheel for keras-applications: filename=Keras_Applications-1.0.8-cp27-none-any.whl size=50703 sha256=9d487522c9caba981933c397420eca5d59f421424257cbda9e7c2ef813129fce
#   Stored in directory: /root/.cache/pip/wheels/dd/f2/5d/2689b5547f32c4e258c3b7ccbe7f1d0f2afbb84fb01e830792
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.5.3-cp27-none-any.whl size=19446 sha256=b9fe701dd627113ba4dca74cbd7e3ac4b73f31ed6490da45a1c66e94eff3028f
#   Stored in directory: /root/.cache/pip/wheels/29/08/d4/3997fab33f1bdf6f98f062863249a607f81d636b403d4d7de1
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp27-none-any.whl size=4833 sha256=fc63686904c7a9a8ac8d38d6c8bef22e38ec709ec03b90643b4b162a479e4955
#   Stored in directory: /root/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for absl-py (setup.py) ... done
#   Created wheel for absl-py: filename=absl_py-0.15.0-cp27-none-any.whl size=132010 sha256=753db741a8ad7e45c15102dc163889c2b05825ff27839d96ad37d5a4f53e13a1
#   Stored in directory: /root/.cache/pip/wheels/19/f3/f9/f5b598f0b550f4140026ca6a7aa6b016929cefc369b5104df6
# Successfully built grpcio keras-applications gast termcolor absl-py
# Installing collected packages: six, enum34, futures, grpcio, funcsigs, mock, numpy, h5py, keras-applications, wrapt, protobuf, keras-preprocessing, gast, werkzeug, absl-py, markdown, tensorboard, termcolor, tensorflow-estimator, google-pasta, backports.weakref, astor, tensorflow-gpu
#   Found existing installation: numpy 1.13.3
#     Uninstalling numpy-1.13.3:
#       Successfully uninstalled numpy-1.13.3
# Successfully installed absl-py-0.15.0 astor-0.8.1 backports.weakref-1.0.post1 enum34-1.1.10 funcsigs-1.0.2 futures-3.3.0 gast-0.5.3 google-pasta-0.2.0 grpcio-1.41.1 h5py-2.10.0 keras-applications-1.0.8 keras-preprocessing-1.1.2 markdown-3.1.1 mock-3.0.5 numpy-1.16.6 protobuf-3.17.3 six-1.16.0 tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0 termcolor-1.1.0 werkzeug-1.0.1 wrapt-1.14.1

# %%
# !pip2 install torch
# !pip2 install tensorflow==1.14
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch
#   Downloading https://files.pythonhosted.org/packages/46/ca/306bb933a68b888ab1c20ede0342506b85857635f04fb55a56e53065579b/torch-1.4.0-cp27-cp27mu-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 20kB/s
# Installing collected packages: torch
# Successfully installed torch-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/d3/59/d88fe8c58ffb66aca21d03c0e290cd68327cc133591130c674985e98a482/tensorflow-1.14.0-cp27-cp27mu-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 103kB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.41.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (3.0.5)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.14.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (3.17.3)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (0.5.3)
# Requirement already satisfied: wheel in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (0.37.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.16.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.16.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (0.15.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: backports.weakref>=1.0rc1 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.0.post1)
# Requirement already satisfied: enum34>=1.1.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (1.1.10)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: futures>=2.2.0; python_version < "3.2" in /usr/local/lib/python2.7/dist-packages (from grpcio>=1.8.6->tensorflow==1.14) (3.3.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow==1.14) (1.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python2.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (44.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python2.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python2.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.1.1)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-1.14.0

# %%
# !git clone https://github.com/salesforce/ctrl
# Out:
# Cloning into 'ctrl'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 163 (delta 29), reused 27 (delta 26), pack-reused 128
# Receiving objects: 100% (163/163), 24.45 MiB | 8.94 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
# %cd ctrl/
# Out:
# /content/ctrl

# %%
# !pip2 install fastBPE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastBPE
#   Downloading https://files.pythonhosted.org/packages/e1/37/f97181428a5d151501b90b2cebedf97c81b034ace753606a3cda5ad4e6e2/fastBPE-0.1.0.tar.gz
# Building wheels for collected packages: fastBPE
#   Building wheel for fastBPE (setup.py) ... done
#   Created wheel for fastBPE: filename=fastBPE-0.1.0-cp27-cp27mu-linux_x86_64.whl size=476484 sha256=c2a0e2d7bd74e0734aa8934b28d69a427834b8ce4b21149fe12d299d07e0ab1a
#   Stored in directory: /root/.cache/pip/wheels/f3/0c/9c/fc62058b4d473a5602bcd3d3edfece796f123875379ea82d79
# Successfully built fastBPE
# Installing collected packages: fastBPE
# Successfully installed fastBPE-0.1.0

# %%
# !pip2 install gsutil
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gsutil
#   Downloading https://files.pythonhosted.org/packages/61/fa/141c0442313662c85a0b92cbf3f3bfbb9bb40a17cc61ded36738f5c68f35/gsutil-4.68.tar.gz (2.9MB)
#      |████████████████████████████████| 2.9MB 18.7MB/s
# Collecting argcomplete>=1.9.4
#   Downloading https://files.pythonhosted.org/packages/b7/9e/9dc74d330c07866d72f62d553fe8bdbe32786ff247a14e68b5659963e6bd/argcomplete-1.12.3-py2.py3-none-any.whl
# Collecting crcmod>=1.7
#   Downloading https://files.pythonhosted.org/packages/6b/b0/e595ce2a2527e169c3bcd6c33d2473c1918e0b7f6826a043ca1245dd4e5b/crcmod-1.7.tar.gz (89kB)
#      |████████████████████████████████| 92kB 10.9MB/s
# Collecting fasteners>=0.14.1
#   Downloading https://files.pythonhosted.org/packages/31/91/6630ebd169ca170634ca8a10dfcc5f5c11b0621672d4c2c9e40381c6d81a/fasteners-0.16.3-py2.py3-none-any.whl
# Collecting gcs-oauth2-boto-plugin>=2.7
#   Downloading https://files.pythonhosted.org/packages/05/e5/3162be0abab32f152f331423426471935f286dd4ad70fa704f2a34ea3c1e/gcs-oauth2-boto-plugin-3.0.tar.gz
# Collecting google-apitools>=0.5.32
#   Downloading https://files.pythonhosted.org/packages/dc/eb/c26c36463a769a3a9f08847b9bf218cb629ca91877a911bbd6dcf37d9e62/google-apitools-0.5.32.tar.gz (172kB)
#      |████████████████████████████████| 174kB 48.6MB/s
# Collecting httplib2>=0.18
#   Downloading https://files.pythonhosted.org/packages/9c/65/57ad964eb8d45cc3d1316ce5ada2632f74e35863a0e57a52398416a182a1/httplib2-0.20.4.tar.gz (349kB)
#      |████████████████████████████████| 358kB 43.6MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting google-reauth>=0.1.0
#   Downloading https://files.pythonhosted.org/packages/69/e1/67ffaa3a645b86318ce30717af7145070ebccec5eef5c623ae08b86129b8/google_reauth-0.1.1-py2.py3-none-any.whl
# Collecting monotonic>=1.4
#   Downloading https://files.pythonhosted.org/packages/9a/67/7e8406a29b6c45be7af7740456f7f37025f0506ae2e05fb9009a53946860/monotonic-1.6-py2.py3-none-any.whl
# Collecting pyOpenSSL>=0.13
#   Downloading https://files.pythonhosted.org/packages/85/3a/fe3c98435856a1ed798977981f3da82d2685cf9df97e4d9546340d2b83db/pyOpenSSL-21.0.0-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 8.9MB/s
# Collecting retry_decorator>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/6e/e6/bedc75b264cbcbf6e6d0e5071d96d739f540fc09be31744a7a8824c02a8e/retry_decorator-1.1.1.tar.gz
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python2.7/dist-packages (from gsutil) (1.16.0)
# Requirement already satisfied: mock<=3.0.5,>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from gsutil) (3.0.5)
# Collecting importlib-metadata<5,>=0.23; python_version == "2.7"
#   Downloading https://files.pythonhosted.org/packages/cf/b4/877779cd7b5a15536ecbe0655cfb35a0de0ede6d888151fd7356d278c47d/importlib_metadata-2.1.3-py2.py3-none-any.whl
# ERROR: Could not find a version that satisfies the requirement rsa==4.7.2 (from gcs-oauth2-boto-plugin>=2.7->gsutil) (from versions: 1.1, 1.2, 1.3, 1.3.1, 1.3.2, 1.3.3, 3.0, 3.0.1, 3.1, 3.1.1, 3.1.2, 3.1.4, 3.2, 3.2.2, 3.2.3, 3.3, 3.4, 3.4.1, 3.4.2, 4.0, 4.1.1, 4.2, 4.3, 4.4, 4.5, 4.7.1)
# ERROR: No matching distribution found for rsa==4.7.2 (from gcs-oauth2-boto-plugin>=2.7->gsutil)

# %%
# !gsutil -m cp -r gs://sf-ctrl/seqlen256_v1.ckpt .
# Out:
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/checkpoint...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.meta...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.data-00000-of-00001...
# Copying gs://sf-ctrl/seqlen256_v1.ckpt/model.ckpt-413000.index...
# | [4/4 files][ 12.7 GiB/ 12.7 GiB] 100% Done  59.1 MiB/s ETA 00:00:00
# Operation completed over 4 objects/12.7 GiB.

# %%
# !pip2 install future
# !pip2 install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting future
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 30.6MB/s
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp27-none-any.whl size=502568 sha256=2a019cfe2b370e079a362f826091c91efd28cbc17265ec90eb193fa72a61a4aa
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: future
# Successfully installed future-0.18.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/8a/c4/d15f1e627fff25443ded77ea70a7b5532d6371498f9285d44d62587e209c/tqdm-4.64.0-py2.py3-none-any.whl (78kB)
#      |████████████████████████████████| 81kB 8.8MB/s
# Collecting importlib-resources; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/8d/94/2f6ceee0c4e63bff0177c07e68d27c937a19f6bc77c4739755b49f5adb04/importlib_resources-3.3.1-py2.py3-none-any.whl
# Collecting typing; python_version < "3.5"
#   Downloading https://files.pythonhosted.org/packages/0b/cb/da856e81731833b94da70a08712f658416266a5fb2a9d9e426c8061becef/typing-3.10.0.0-py2-none-any.whl
# Collecting contextlib2; python_version < "3"
#   Downloading https://files.pythonhosted.org/packages/85/60/370352f7ef6aa96c52fb001831622f50f923c1d575427d021b8ab3311236/contextlib2-0.6.0.post1-py2.py3-none-any.whl
# Collecting pathlib2; python_version < "3"
#   Downloading https://files.pythonhosted.org/packages/09/eb/4af4bcd5b8731366b676192675221c5324394a580dfae469d498313b5c4a/pathlib2-2.3.7.post1-py2.py3-none-any.whl
# Collecting zipp>=0.4; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/96/0a/67556e9b7782df7118c1f49bdc494da5e5e429c93aa77965f33e81287c8c/zipp-1.2.0-py2.py3-none-any.whl
# Collecting singledispatch; python_version < "3.4"
#   Downloading https://files.pythonhosted.org/packages/3f/09/2a17c6505a8373229cb3de6161e3af74ff90afcf4516719aa6cf32fad151/singledispatch-3.7.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from pathlib2; python_version < "3"->importlib-resources; python_version < "3.7"->tqdm) (1.16.0)
# Collecting scandir; python_version < "3.5"
#   Downloading https://files.pythonhosted.org/packages/df/f5/9c052db7bd54d0cbf1bc0bb6554362bba1012d03e5888950a4f5c5dadc4e/scandir-1.10.0.tar.gz
# Building wheels for collected packages: scandir
#   Building wheel for scandir (setup.py) ... done
#   Created wheel for scandir: filename=scandir-1.10.0-cp27-cp27mu-linux_x86_64.whl size=33231 sha256=eb064efb83bae7d9a7ba7985ef5e15a23c51d0f2aa8483f25c35bc2a8e2d3412
#   Stored in directory: /root/.cache/pip/wheels/91/95/75/19c98a91239878abbc7c59970abd3b4e0438a7dd5b61778335
# Successfully built scandir
# Installing collected packages: typing, contextlib2, scandir, pathlib2, zipp, singledispatch, importlib-resources, tqdm
# Successfully installed contextlib2-0.6.0.post1 importlib-resources-3.3.1 pathlib2-2.3.7.post1 scandir-1.10.0 singledispatch-3.7.0 tqdm-4.64.0 typing-3.10.0.0 zipp-1.2.0

# %%
# !python2 pytorch_generation.py --temperature 0.5 --model seqlen256_v1.ckpt/model.ckpt-413000.data-00000-of-00001 --print_once
# Out:
# 246534 unique words
# tcmalloc: large alloc 1262256128 bytes == 0x557666920000 @  0x7f93967dbb6b 0x7f93967fb379 0x7f9341755b4a 0x7f93417575fa 0x7f9343a8778a 0x7f9343cd030b 0x7f9343d17b37 0x7f9343a880b0 0x7f9343a91d95 0x7f9343dcb973 0x7f9343e0f709 0x7f938c835c43 0x7f938c60cadb 0x55765a43eeaa 0x55765a43c70a 0x55765a457ca9 0x55765a47021e 0x55765a46fdca 0x55765a42d5bb 0x55765a443f60 0x55765a43c70a 0x55765a43c039 0x55765a46c46f 0x55765a4676f2 0x55765a46711d 0x55765a416799 0x7f93963f6c87 0x55765a41612a
# Loading vocabulary from vocab ...
# Read 6086453827 words (246531 unique) from vocabulary file.
# Loading codes from codes ...
# Read 200000 codes from the codes file.
# Found PyTorch checkpoint @ 5d11fdadc5aa3b7e75036e3df8c58c2b
# Loading instead of converting from TensorFlow
# tcmalloc: large alloc 1262256128 bytes == 0x55785fee8000 @  0x7f93967dbb6b 0x7f93967fb379 0x7f9341755b4a 0x7f93417575fa 0x7f9343e5a4af 0x7f9343e5a56d 0x7f938c8d5380 0x55765a42d4e5 0x55765a443f60 0x55765a43c70a 0x55765a457ca9 0x55765a42843e 0x55765a3d7251 0x55765a3d66f2 0x55765a44429d 0x55765a43c70a 0x55765a457f4c 0x55765a42843e 0x55765a44144d 0x55765a43c70a 0x55765a44414e 0x55765a43c70a 0x55765a43c039 0x55765a46c46f 0x55765a4676f2 0x55765a46711d 0x55765a416799 0x7f93963f6c87 0x55765a41612a
# ENTER PROMPT: Event PRO great change
# ---------------------------------------
# Event PRO great change for me to be able to enjoy my new job without having to worry about a broken leg.
#
#  **TL;DR** I broke both of my legs, and now I'm on crutches while getting used to them. If you have any questions or comments please feel free to ask. Also if anyone has the slightest idea how to get rid of that horrible taste in your mouth from all those salty foods, let me know. Thanks again!
#
#  Edit 1: Thank you guys so much for all the kind words. It really means a lot when people take time out of their day just to help someone else. The only thing left is finding some work where I can afford it but even then I'll probably go back into school because it's what keeps me going. I've had many offers already though mostly at jobs with more than one person working together but that's not something I'd want right now. My main concern here was being honest and giving everyone an accurate picture of what happened and this community helped quite a bit. It's nice knowing there are other folks who care as much as I do.
#
#  Edit2: Apparently I should add a disclaimer here. This isn't meant to make light of anything nor did I intend to cause anybody pain. However, after going through this whole ordeal myself, I can't imagine doing things like this. And no matter what, I will never forget
#
# ENTER PROMPT: News PRO great joy
# ---------------------------------------
# News PRO great joy in the knowledge that he is still a part of our game.
#  ''I don't think it's going to be any different than when I was at St. Louis. I've always been proud of what we have accomplished here and I'm looking forward to continuing it.''
#  The Saints are hoping the same can happen for their new coach, who replaces Mike Ditka, whom they fired after last season.
#  ''We're excited about having Coach Payton as an assistant coach,'' said quarterback Drew Bledsoe, who will make his first start since breaking a bone in his left hand on Nov. 29. ''He knows how important it is. He understands it, too. He's going to bring some things from Chicago with him. That's really what's so exciting.''
#  It has not worked out well for teams like New England or Green Bay, but the Saints hope Payton's familiarity will help them win more games. Earlier this season, San Francisco coach Steve Mariucci told reporters before the season began that Payton would probably go back to Chicago. But Payton did not. His departure means the 49ers must replace him immediately.
#  How much difference does all that make? Well, if there were no change, then Favre might look very different. In fact, given Favre's recent struggles -- including four consecutive starts without throwing touchdown passes -- the Packers may feel compelled to trade him, which could open up even more roster
#
# ENTER PROMPT: Gaming PRO problem
# ---------------------------------------
# Gaming PRO problem with the product is that it has a very tight fit. I had to use some tape on my USB ports in order for the cord not to fall out of it.
#  Rating: 2.0
#  This item was great when we first got it, but after about two weeks of use, one port stopped working and now it's just another useless piece of plastic lying around our house. Not worth the money. Very disappointed since this would have been perfect if only it worked. :(
#  Rating: 2.0
#  Bought these because they were cheap enough and looked like they'd work fine, but both hubs quit within 3 months. The blue light doesn't even come on, so I'm assuming there's something wrong inside. Bummer. Don't waste your time.
#  Rating: 2.0
#  It works fine as long as you don't move or bump them. If you're using them more than once every day then you'll be disappointed. They are made cheaply and will break easily.
#  Rating: 2.0
#  I purchased 2 of these. One worked well enough, the other didn't. No way to know which one, until I plugged it into an old computer running Windows XP. When I tried plugging it in, there was no power, although the lights came on. After unplugging, the power LED stayed lit, indicating power. However, when I attempted to plug anything else (mouse, keyboard, etc.) into either port, nothing happened. Neither hub could detect
#
# ENTER PROMPT: Technologies PRO ability to have an intellectual exchange at level.
# ---------------------------------------
# Technologies PRO ability to have an intellectual exchange at level.
#  Text: I was told by a fellow redditor that there is no way for the average user to get their hands on something like this without having some level of technical knowledge and experience. They were saying that they would be able to take your work and turn it into a document with pictures or other digital media. This seemed very cool but then i realized that if you are using ProTools as part of your studio workflow you will need to know what these things are. What kind of tools do we use in ProTools? How does one go about learning how to make a video from scratch? Where should I start looking? And so on. The more I thought about it, the less sense it made to me when someone said that Pro Tools users could just download everything off the internet and plug them in. It seems like such a waste of time and effort since most people can only afford basic computers anyway. So my question is, where do pro audio producers come up with all this?
#
#  Edit: Thanks everyone who gave input here. I think I've got a better idea now :)
#
#  Edit 2: My answer below has been downvoted out of existence :(
#  _____
#  &gt; *Hello, users of CMV! This is a footnote from your moderators.
#
# ENTER PROMPT: Pregnancy PRO joy.
# ---------------------------------------
# Pregnancy PRO joy.
#  Text: I had my first cervical check this morning and LO was measuring at 8lbs 9oz so I'm not too worried. Now to figure out how much formula I've been giving him :) The nurse said the baby is doing great but also that she's scared of going in for a c-section because she thinks it could be scary. She told me NOT TO GIVE HIM ANY MORE THAN 2 - 3 TIMES A DAY. So we will see what happens when he comes.
#
#  Edit: My husband went back into work today after being gone all day with some other family members who were visiting from across country. He came home around noon and got his stuff together and then left. He's currently working on getting everything ready to go home. When he's done he'll come pick us up again tomorrow. We are hoping to have our son by Tuesday or Wednesday depending on whether they schedule an induction date yet. Hopefully that's sooner than later.
#
#  Edit 2: SO has decided to leave today as well. He says its easier having someone else there while he goes through things with me. And just wanted to thank everyone here for your support throughout pregnancy and postpartum. You guys rock!
#
#  Thanks again!! &lt;3
#
#  Also if anyone wants more info about labor I'll post pics soon.
#
#  Edit# 3: Just
#
# ENTER PROMPT: Atheism PRO moral nihilism.
# ---------------------------------------
# Atheism PRO moral nihilism.
#  Text: I was raised in a very religious family. You came home from church and your father would take you to the local ice cream shop (whatever that was) for some free money. This is where my parents started teaching me about morality. They taught us how it should be done, but they also told us not to do it. My dad said he did this because when people are forced to do something, it's hard on them emotionally or physically. When someone does something without thinking of consequences, that's called immoral. That's what morality is. So if you're going out with friends one night, you can have sex with as many women as long as they're willing. If you want to go into business together, then yes, you need to pay taxes. But don't get mad at me if I can't afford to buy a new car every year. Don't call me immoral just because I'm broke. Morality isn't based off money, it's based off morals that we feel right now. We shouldn't judge other people. It doesn't matter whether its right or wrong. It's our choice. And so on.
#
#  The thing is, I grew up believing this. That there were no consequences whatsoever for any actions taken. A lot of things happened back then, and I never knew why. However, I've gotten older now and realized that most everything has consequences. Everything happens around you. Everyone will die eventually. There aren't too many
#
# ENTER PROMPT: Tip PRO arrest.
# ---------------------------------------
# Tip PRO arrest.
#  Text: I'm a bit of an amateur with police work and have heard that if you arrest someone for something like driving without insurance or speeding, then the arresting officer can charge them with DUI even though they didn't actually do anything wrong. What is your opinion on this? If it wasn't illegal to drink when driving, wouldn't this be illegal? (Also, what about people who are caught drinking while driving? Would those charges still apply in such cases?)
#  Edit: Thanks everyone, great question! I'll make sure to check out some other subreddits as well. :)
#  Edit 2: I've decided not to use any names because they're anonymous. The only person involved was my brother so it's safe enough but there were several others involved. Many thanks again everyone! :D
#
#  **TL;DR** - My mom had been arrested twice before from drunk driving. She has since passed away and we don't know her real name. We found out she died recently via friends looking up information online. Should these arrests remain legal despite no evidence being found? Is anyone familiar with laws pertaining to drunk-driver arrests?
#
#  Update: Thank you all very much for taking time to answer questions today. It really helped me understand where things stand regarding whether or not this would be legal. One thing that's important to note though, that I
#
# ENTER PROMPT: Teenager PRO accident.
# WARNING! You are not starting your generation from a control code so you won't get good results
# ---------------------------------------
# Teenager PRO accident.
#
#  &gt;The unfortunate accident occurred when the young man was in a bicycle seat and fell off his bikewhile riding down a steep embankment into the river below. He had to be resuscitated.&lt;&lt; &lt;&lt; &lt;&lt; &lt;&lt; &lt; &gt;
#
#  &lt;&lt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &gt; &
#
# ENTER PROMPT: Teenage PRO accident
# ---------------------------------------
# Teenage PRO accident while driving a car and I was in the hospital for 2 weeks.
#  Text: This happened on Friday night around 1 a.m. My friend who is also my manager at work got me into his car to drive her home from work. We were both pretty drunk so we just kept driving. After about an hour of driving, she said that it was getting dark out and asked if there was any way we could stop somewhere before going home. She had no idea how far away this place was, but knew where the town center was. So i told her that we should go over there. When we stopped by the gas station, they gave us some gas. The next thing I remember is, I woke up in the hospital. They put me back together with only one arm because apparently that hurt even worse than before. It took them two days to get everything sorted out. Because I wasn't allowed to drive, I couldn't do anything until then. But what really made things worst was when I went to school on Monday. Everything seemed normal there, but as soon as class ended, all hell broke loose. There were fights between students everywhere. Some people started throwing rocks at other students, which resulted in several injuries. One girl ended up breaking her arm. Another student ran into traffic and died. And then last night, someone threw acid inside our school. I'm still not sure why anyone would want to throw
#
# ENTER PROMPT: multilingual PRO problem
# ---------------------------------------
# multilingual PRO problem
#  - Problème de la garantie de l'unité d'unités (ou des classes de valeurs)
#  - Problèmes avec les fonctions et les méthodes définies par le code ISO 9001 :
#  - Les produits doivent être conformes à un ensemble spécifique ;
#  - La documentation doit faire référence aux normes internationales existantes ;
#  - Le contenu du site web est pris en compte dans l’évaluation technique d’une demande ( ou des critères pour sélectionner ) ;
#  - Les procédures sont clairement explicitées sur le site web.
#
#  Voir aussi.
#  Articles connexes.
#  - Liste de codes-barres
#  Liens externes.
#  - Présentation d'un prototype de base de données RQD - Version 1.0
#
#  Bibliographie.
#  - .
#
#
#  David L. Donahoe
#
#  David Lawrence Donahoe, né le , est un astronaute canadien. Il a été directeur adjoint scientifique au Jet Propulsion Laboratory (JPL) entre 1994 et 1996. Il fut vice-président de l'American Astronomical Society (AAS) entre 1997 et 2000. En 2002, il enseign
#
# ENTER PROMPT:
