# %% [markdown]
# ## **File Pre-Processing**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NewVend/TopTenToKialo
# Out:
# /content/drive/.shortcut-targets-by-id/1gCIByQUC8gNPV0rYXtm74U-qo12KfCqO/NewVend/TopTenToKialo

# %% [markdown]
# ## **Initializing & Installations**

# %%
from IPython.display import clear_output

# %%
# !pip install tensorflow==1.14
# !pip install tensorflow-gpu==1.14
# !pip install tensorboard==1.14.0
# !pip install requests
# !pip install scikit-learn==0.22.2.post1
# !pip install nltk
# !pip install tqdm
# !pip install numpy==1.18.5
# !pip install gast==0.2.2
# !pip install protobuf==3.20.*
# !pip install fastBPE
clear_output()

# %%
# !patch -b /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/keras.py estimator.patch
# Out:
# patching file /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/keras.py
# Hunk #1 FAILED at 47.
# Hunk #2 FAILED at 228.
# Hunk #3 FAILED at 239.
# Hunk #4 FAILED at 448.
# Hunk #5 FAILED at 462.
# patch: **** Can't reopen file /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/keras.py : No such file or directory

# %% [markdown]
# ## **Genaration**

# %%
# %run generation.py --model_dir ckpt --inp r-v45.xlsx --inp_col Aspects --print_once
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /content/drive/.shortcut-targets-by-id/1gCIByQUC8gNPV0rYXtm74U-qo12KfCqO/NewVend/TopTenToKialo/generation.py in <module>
#       5 import numpy as np
#       6 from tqdm import tqdm
# ----> 7 tf.enable_eager_execution()
#       8 import transformer
#       9 import argparse
#
# AttributeError: module 'tensorflow' has no attribute 'enable_eager_execution'
