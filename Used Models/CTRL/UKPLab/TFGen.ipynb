# %%
from IPython.display import clear_output

# %%
i = 1
name = './T3/Result/ANN/result_'+ "hudai" +'.xlsx'
name
# Out:
# './T3/Result/ANN/result_1.xlsx'

# %%
an = 10
nan = 50
print('---------------------------Report for ' + str(i) + ' QF---------------------------')
total = an + nan
anp = (an/total) * 100
nanp = (nan/total) * 100
print('Total 0 : %d\tTotal 1: %d\n\nIn Percentage\n\nTotal 0 : %.2f\tTotal 1: %.2f\n' % (an, nan, anp, nanp))
# Out:
# ---------------------------Report for 1 QF---------------------------
# Total 0 : 10	Total 1: 50
#
# In Percentage
#
# Total 0 : 16.67	Total 1: 83.33

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/NewVend/TopTenToKialo
# Out:
# /content/gdrive/MyDrive/NewVend/TopTenToKialo

# %%
# !pip install gsutil

# %%
# !gsutil config

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'rising-pen-358018'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://ytosko/

# %%
bucket_name = 'ytosko'
# !gsutil -m cp -r /content/gdrive/MyDrive/NewVend/TopTenToKialo/* gs://{bucket_name}/TopTenToKialo

# %%
# !pip install tensorflow==1.14
# !pip install tensorflow-gpu==1.14
# !pip install tensorflow-estimator==1.14.0
# !pip install tensorboard==1.14.0
clear_output()

# %%
# !pip install requests
# !pip install regex
# !pip install scikit-learn==0.22.2.post1
# !pip install seaborn
# !pip install rouge-score
# !pip install elasticsearch
# !pip install justext
# !pip install warcio==1.7.3
# !pip install nltk
# !pip install tqdm
clear_output()

# %%
# !pip install fastbpe
# !pip install argparse
# !pip install protobuf==3.20.*
# !pip install gast==0.2.2
# !pip install numpy==1.18.5
clear_output()

# %%
# !patch -b /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/keras.py estimator.patch
# Out:
# patching file /usr/local/lib/python3.7/dist-packages/tensorflow_estimator/python/estimator/keras.py

# %%
import numpy as np
import requests
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
import pandas as pd
import os
import tqdm
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
folder = './training_utils/'
filed = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]
filed[:5]
# Out:
# ['search_PRO_people.tfrecords',
#  'search_PRO_dislike.tfrecords',
#  'search_PRO_cheated.tfrecords',
#  'search_PRO_living.tfrecords',
#  'search_PRO_maximizing.tfrecords']

# %%
# !rm -rf training_utils

# %%
# !mkdir training_utils

# %%
# !mkdir reddit_seqlen256_v1

# %%
for x in range(len(filed)):
  filed[x] = './training_data/kialo/' + filed[x] + '/final/'
filed[:5]
# Out:
# ['./training_data/kialo/school/final/',
#  './training_data/kialo/search/final/',
#  './training_data/kialo/bitter/final/',
#  './training_data/kialo/maybe/final/',
#  './training_data/kialo/lie/final/']

# %%
for x in range(len(filed)):
    oxi = filed[x]
    # %run make_tf_records_multitag.py --files_folder '$oxi' --sequence_len 256

# %%
weight = 'reddit_seqlen256_v1'
steps = 157

# %%
# %run training.py --model_dir '$weight' --iterations $steps
# Out:
# 246534 unique words
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# tied_embedding_softmax_1 (TiedE multiple             315810054   input_2[0][0]
#                                                                  encoder_1[0][0]
# __________________________________________________________________________________________________
# encoder_1 (Encoder)             (None, 256, 1280)    1322154496  tied_embedding_softmax_1[0][0]
# ...
# Total params: 1,637,964,550
# Trainable params: 1,637,964,550
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# INFO:tensorflow:Using the Keras model provided.
